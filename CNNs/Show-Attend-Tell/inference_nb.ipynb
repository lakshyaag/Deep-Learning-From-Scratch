# %%
# !ls data/models
# Out:
# best_model.pth	final_model.pth  image_captioning_model_attn.pth

# %%
# %cd Deep-Learning-From-Scratch/CNNs/Show-Attend-Tell/
# %run ./inference.py --model_path ./data/models/final_model.pth --image_path ./data/test_image.jpg
# %run ./inference.py --model_path ./data/models/final_model.pth --image_path ./data/test_image_2.jpg
# %run ./inference.py --model_path ./data/models/final_model.pth --image_path ./data/test_image_3.jpg
# %run ./inference.py --model_path ./data/models/final_model.pth --image_path ./data/test_image_4.jpg
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# [Errno 2] No such file or directory: 'Deep-Learning-From-Scratch/CNNs/Show-Attend-Tell/'
# /teamspace/studios/this_studio/Deep-Learning-From-Scratch/CNNs/Show-Attend-Tell
# Total number of tokens in vocabulary: 2995
# Sample tokenized caption: [4, 19, 5, 16, 28]
# Generated caption: <SOS> a man in a man in a <UNK> <EOS>
# Total number of tokens in vocabulary: 2995
# Sample tokenized caption: [4, 19, 5, 16, 28]
# Generated caption: <SOS> a man in a black and white dog <EOS>
# Total number of tokens in vocabulary: 2995
# Sample tokenized caption: [4, 19, 5, 16, 28]
# Generated caption: <SOS> a man in a man in a <UNK> <EOS>
# Total number of tokens in vocabulary: 2995
# Sample tokenized caption: [4, 19, 5, 16, 28]
# ...
