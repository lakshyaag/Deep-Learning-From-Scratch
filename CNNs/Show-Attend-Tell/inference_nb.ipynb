# %%
# !ls data/models/ -lta
# Out:
# ls: cannot access 'data/models/': No such file or directory

# %%
# %cd Deep-Learning-From-Scratch/CNNs/Show-Attend-Tell/
# %run ./inference.py --model_path ./data/models/model_epoch_10.pth --image_path ./data/test_image.jpg --beam_size=30
# %run ./inference.py --model_path ./data/models/model_epoch_10.pth --image_path ./data/test_image_2.jpg --beam_size=30
# %run ./inference.py --model_path ./data/models/model_epoch_10.pth --image_path ./data/test_image_3.jpg --beam_size=30
# %run ./inference.py --model_path ./data/models/model_epoch_10.pth --image_path ./data/test_image_4.jpg --beam_size=30
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /teamspace/studios/this_studio/Deep-Learning-From-Scratch/CNNs/Show-Attend-Tell
# Total number of tokens in vocabulary: 2995
# Sample tokenized caption: [4, 19, 5, 16, 28]
# Generated caption: <SOS> a man stands in the snow <EOS>
# Total number of tokens in vocabulary: 2995
# Sample tokenized caption: [4, 19, 5, 16, 28]
# Generated caption: <SOS> a black and white dog is running through the grass <EOS>
# Total number of tokens in vocabulary: 2995
# Sample tokenized caption: [4, 19, 5, 16, 28]
# Generated caption: <SOS> a person stands in the snow <EOS>
# Total number of tokens in vocabulary: 2995
# Sample tokenized caption: [4, 19, 5, 16, 28]
# Generated caption: <SOS> a dog running through water <EOS>

# %%
from rich import print

# %load_ext rich
# Out:
# The rich extension is already loaded. To reload it, use:
#   %reload_ext rich

# %%
from IPython.display import FileLink
FileLink("./data/models/model_epoch_10.pth")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# /teamspace/studios/this_studio/Deep-Learning-From-Scratch/CNNs/Show-Attend-Tell/data/models/model_epoch_10.pth
